# %% [markdown]
# # Lecture Exercise 14 - Gradient Descent

# %% [markdown]
# ## 1) Objective
# Use our understanding of gradient descent to calculate the ideal distance between two atoms.

# %% [markdown]
# ## 2) Preparation
# Only two imports are needed for plotting.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3) Lennard Jones
# We will model how the potential energy between two atoms depends on their distance. A common simplified model is the Lennard-Jones potential:
# $$
# LJ(r) = 4\epsilon \left[\left(\frac{\sigma}{r}\right)^{12} - \left(\frac{\sigma}{r}\right)^6 \right]
# $$
# Where:
# - $r$ = distance between atoms
# - $\epsilon$ = depth of energy well
# - $\sigma$ = distance where the potential is zero

# %% [markdown]
# ### 3.1 LJ Function
# Write a function using ```def``` that computes the Lennard-Jones potential for a given $r$, $\epsilon$, and $\sigma$.

# %%
""" your code here """
# Out:
# ' your code here '

# %% [markdown]
# ### 3.2 Plotting
# We will be modeling two Argon atoms, the typical parameters used for this are $\epsilon = 0.997$, $\sigma = 3.4$, and $r$ from 3 to 7 $\overset{\circ}{A}$. Plot $LJ(r)$ using the function you wrote in 3.1). What do you observe about the graph? Print the ideal radius at which the potential reaches a minimum and print the value.

# %%
""" your code here """
# Out:
# ' your code here '

# %% [markdown]
# ## 4) Deriviative
# Now, implement a function that calculates the derivative of LJ energy, this corresponds to the force:
# $$
# LJ'(r) = 4\epsilon \left( -\frac{12\sigma^{12}}{r^{13}} + \frac{6\sigma^{6}}{r^{7}} \right)
# $$

# %%
""" your code here """
# Out:
# ' your code here '

# %% [markdown]
# ## 5) Gradient Descent
# ### 5.1
# Write a function using ```def``` that runs gradient descent<br>
# <br>
# $r_{t+1} = r_t - \alpha\,LJ'(r)$<br>
# <br>
# for 20 iterations that aims to find the value for $r$ that corresponds to minimium energy. Start from $r = 3$ and use $\alpha = 0.01$. Print the radius, LJ energy and the derivative for each iteration $t$. Use the same $\epsilon$ and $\sigma$ as above. How close do you get to the minimum?

# %%
""" your code here """
# Out:
# ' your code here '

# %% [markdown]
# your answer here.

# %% [markdown]
# ### 5.2
# Now, change the $\alpha$ to 0.05. What happens? What if you were to run this for 200 iterations?

# %%
""" your code here """
# Out:
# ' your code here '

# %% [markdown]
# your answer here.

# %% [markdown]
# ## 6) Optional Extra Exercise
# Try graphing these results using a smooth plot for the LJ energy curve and a scatter plot for each iteration through the Gradient Descent loop.

# %%
""" your code here """
# Out:
# ' your code here '

# %%
""" your code here """
# Out:
# ' your code here '
