# %% [markdown]
# # Problem Set 5 - Revisiting Data

# %% [markdown]
# ## 1) Objective
# In this exercise we want to revisit the UCI Heart Disease (Cleveland) Dataset and run it on<br>
# - logistic regression
# - an ANN
# - an ANN after PCA<br>

# %% [markdown]
# and compare performance (accuracy and mean cross entropy). We therefore want to find out if an ANN is *always* a much better option.

# %% [markdown]
# ## 2) Preparation

# %% [markdown]
# We call all the libraries needed:

# %%
# standard libraries
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import svm
import matplotlib.pyplot as plt

# for building an ANN via Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers 

# log regression as benchmark:
import statsmodels.api as sm

#for pca
from sklearn.decomposition import PCA

# libraries for processing the data 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## 3) Data
#
# We will be using the UCI Heart Disease (Cleveland) Dataset (see LE 13)

# %%
url          = "https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data"

columns      = ["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal", "target"]

df           = pd.read_csv(url, names=columns)
df["target"] = (df["target"] > 0).astype(int) # make binary 

# Replace '?' with nan, then drop nas
df = df.replace("?", pd.NA)
df = df.dropna()
df.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  target
# 0    3.0  0.0  6.0       0
# 1    2.0  3.0  3.0       1
# 2    2.0  2.0  7.0       1
# 3    3.0  0.0  3.0       0
# 4    1.0  0.0  3.0       0

# %% [markdown]
# ## 4) Data Preparation
# Split the dataset into training and testing sets (80/20), one-hot encode the following categorical features: `cp`, `thal`, `slope`, `restecg` and scale the data like you did in LE 13.

# %%
#use your code from LE 13 here

# %% [markdown]
# ## 5) Logistic Regression
# **5.1** Run a logistic regression on the dataset, evaluate test accuracy, generate a confusion matrix plot and a cross entropy plot (both from the test set). Store the accuracy and the mean cross entropy in a variable each. We will need those values later.

# %% [markdown]
# **running the model:**

# %%
"""your code here"""
# Out:
# 'your code here'

# %% [markdown]
# **evaluation**

# %%
"""your code here"""
# Out:
# 'your code here'

# %%
# confusion matrix
"""your code here"""
# Out:
# 'your code here'

# %%
"""your code here"""
#accuracy_Log      = 100*(np.array(y_test) == PredY_Log).sum()/len(PredY_Log)
#print(f'accuracy = {accuracy_Log: .2f}%')
# Out:
# 'your code here'

# %%
"""your code here"""
#BCE_tot_Log = - np.log(probs_class0).sum() - np.log(probs_class1).sum()
#BCE_tot_Log = BCE_tot_Log/len(PredY_Log)
# Out:
# 'your code here'

# %%
#print(f'total cross entropy = {BCE_tot_Log: .2f}')

# %% [markdown]
# ## 6) The ANN
# **6.1** Now, run a simple ANN on the dataset. Prevent overfitting.<br>
# What happens if you train the ANN for a large number of neurons (say 64) vs for a relatively small number (say 3)?<br>
# Try to improve the result by experimenting with different activation functions for the input layer, different number of neurons, different ratios train/validation and different drop-out rates. How easy/difficult is it to reach the same performance as with the logistic regression model?<br>
# For your best fit: Evaluate test accuracy, generate a confusion matrix plot and a cross entropy plot (both from the test set). Store the accuracy and the mean cross entropy in a variable each. We will need those values later.

# %% [markdown]
# The ANN:

# %%
#def My_Keras_Model(input_dim, Nneurons, NClasses, DArate = .8):
"""your code here"""
# Out:
# 'your code here'

# %%
"""your code here"""
# Out:
# 'your code here'

# %%
"""your code here"""
#accuracy_ANN     = 100*(np.array(y_test) == PredY_ANN).sum()/len(PredY_ANN)
#print(f'accuracy = {accuracy_ANN: .2f}%')
# Out:
# 'your code here'

# %%
# confusion matrix
"""your code here"""
# Out:
# 'your code here'

# %%
"""your code here"""
#BCE_tot_ANN = - np.log(probs_class0).sum() - np.log(probs_class1).sum()
#BCE_tot_ANN = BCE_tot_ANN/len(PredY_ANN)
# Out:
# 'your code here'

# %%
#print(f'total cross entropy = {BCE_tot_ANN: .2f}')

# %% [markdown]
# your answer here

# %% [markdown]
# <br>

# %% [markdown]
# **6.2** PCA and ANN: Next, perform a PCA with the data first, plot the eigenvalue spectrum alongside with the cumulative variance. Re-run the ANN with the eigen directions associated with the first five most prominent eigenvalues<br>
# Evaluate test accuracy, generate a confusion matrix plot and a cross entropy plot (both from the test set). Store the accuracy and the mean cross entropy in a variable each. We will need those values later.

# %% [markdown]
# **PCA**

# %%
"""your code here"""
# Out:
# 'your code here'

# %%
"""your code here"""
#ANN after PCA
# Out:
# 'your code here'

# %%
"""your code here"""
#accuracy_ANN_PCA     = 100*(np.array(y_test) == PredY_ANN_PCA).sum()/len(PredY_ANN_PCA)
#print(f'accuracy = {accuracy_ANN_PCA: .2f}%')
# Out:
# 'your code here'

# %%
# confusion matrix
"""your code here"""
# Out:
# 'your code here'

# %%
"""your code here"""
#BCE_tot_ANN_PCA = - np.log(probs_class0).sum() - np.log(probs_class1).sum()
#BCE_tot_ANN_PCA = BCE_tot_ANN_PCA/len(PredY_ANN_PCA)
# Out:
# 'your code here'

# %%
#print(f'total cross entropy = {BCE_tot_ANN_PCA: .2f}')

# %% [markdown]
# **6.3** Finally, compare the three models. Put the accuracy and the total cross entropy from all models in one table (pd.DataFrame) and discuss your findings.

# %%
"""your code here"""
# Out:
# 'your code here'

# %% [markdown]
# your answer here
