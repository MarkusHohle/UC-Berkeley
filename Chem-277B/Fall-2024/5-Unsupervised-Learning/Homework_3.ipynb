# %% [markdown]
# # Chem 277B - Fall 2024 - Homework 3
# ## Gaussian Mixture Models
# *Submit this notebook to bCourses to receive a credit for this assignment.*
# <br>
# due: **Oct 7th 2024**
# <br>
# **Please upload both, the .ipynb file and the corresponding .pdf**<br>
# <br>
# ## Problem (20 P)

# %% [markdown]
# Write a Python script **AnalyzeGMM** using *def*, that clusters the *Iris Dataset* using a **G**aussian **M**ixture **M**odel.
# Use the libraries

# %%
from sklearn import datasets                 #for the iris dataset  
from sklearn.mixture import GaussianMixture  #for running the GMM

# %% [markdown]
# The syntax is:

# %%
my_model   = GaussianMixture(n_components = k, random_state = 0).fit(X)

# %% [markdown]
# The script should perform the following steps:<br>
# In order to visualize the process, run the model first for **three different combinations** of **two features** and evaluate the result via a scatter plot. The figures should look like:

# %% [markdown]
# ![image.png](attachment:1cb496b9-e8bf-439f-9298-336404d1daf5.png)
# ![image.png](attachment:62185928-99a4-4ae5-b5c5-c5a4256d217c.png)
# ![image.png](attachment:acdefdf1-77a1-4a2d-a9e9-4ca5f6d2914b.png)

# %% [markdown]
# Now run the full 4D model for k = 3 cluster. The script should return the accuracy.<br>
# Finally, the script should calculate the silouhette coefficent using

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

# %% [markdown]
# for k = 2 ... 15 and create a plot showing the silouhette coefficent depending on the different k. The plot should look similar to:
# ![image.png](attachment:516b68a7-f028-441d-b09f-8029640276c8.png)

# %% [markdown]
# **Important:** you might get some unrelated, but anoying, warnings. The verbose can be set to zero by importing

# %%
import warnings

# %% [markdown]
# and then calling

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# within the script.
